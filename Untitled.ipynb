# %%
list = [1,2,3,3,5,6,7] 
print(set(list))
# Out:
# {1, 2, 3, 5, 6, 7}

# %%
lst = [1,2,3,4,5]
lst1=[]
lst2=[]
for i in lst :
    if i % 2 == 0:
     lst1.append(i)
    else:
     lst2.append(i)
print("even",lst1)
print("odd",lst2)
# Out:
# even [2, 4]
# odd [1, 3, 5]

# %%
#
lst = [100, 300, 500, 700, 900]

# %%
lst = [20, 21, 16, 15, 14]
lst1 = []
for i in lst:
    if i > 18:
        lst1.append(i)
        print(lst1)
# Out:
# [20]
# [20, 21]

# %%
#
lst = [11, 21, 14, -10]
for i in lst:
    if i < 0:
        print(i)
# Out:
# -10

# %%
lst = [" Aditi", "Stri", "shiro"]
lst.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 2
#       1 str = "PGM COE"
# ----> 2 str.lowercase()
#       3 print(str)
#
# AttributeError: 'str' object has no attribute 'lowercase'

# %%
lst = ["Bhumika"]
lst[0] = "Bhumi"
print(lst)
# Out:
# ['Bhumi']

# %%
lst = ["Bhumika", "Bhumi"]
lst1 = []
lst1.replace("bhumi

# %%
lst = [10, None, 13, None, 45]
for i in lst:
    if i in

# %%
a = int(input("enter any number:"))
print(float(a))
